# %% [markdown]
# # Creating Images
# Grayscale images and Color images

# %%
#grayscale image

import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt

image = np.zeros((8,8) , dtype = np.uint8)
image[0,1] = 255
fig, ax = plt.subplots(1, 1, figsize = (6,8))
ax.imshow(image, cmap = 'gray', vmin = 0, vmax = 255)
ax.xaxis.set_ticks_position('bottom')
plt.show()

# %%
#color image

color_image = np.zeros((8,8,3), dtype = np.uint8)
color_image[0,1] = (255,0,128)
fig, ax = plt.subplots(1, 1, figsize = (8,8))
ax.imshow(color_image)
ax.xaxis.set_ticks_position('bottom')
plt.show()

# %% [markdown]
# Display Using Matplotlib

# %%
im = cv.imread(r'C:\Users\Luchitha\Documents\Python\computer vision\images\cristiano.jpg')
fig, ax = plt.subplots(1, 2, figsize=(8, 8))
ax[0].imshow(im)
ax[0].set_title('BGR Image')
ax[1].imshow(cv.cvtColor(im, cv.COLOR_BGR2RGB))
ax[1].set_title('RGB Image')
plt.show()

# %%
import matplotlib.pyplot as plt
import cv2 as cv

messi = cv.imread(r'C:\Users\Luchitha\Documents\Python\computer vision\images\messi.jpg')

cv.namedWindow('Messi', cv.WINDOW_AUTOSIZE)
cv.imshow('Messi', messi)
cv.waitKey(0)
cv.destroyAllWindows()
